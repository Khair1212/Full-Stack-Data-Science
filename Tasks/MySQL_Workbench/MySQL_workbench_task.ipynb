# %% [markdown]
# # 1. Make Connection with MySQL

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost', user = 'root', passwd = 'khair2255')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     235         try:
# --> 236             self._cmysql.connect(**cnx_kwargs)
#     237             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (10061)
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-2-d30b822e0a34> in <module>
# ----> 1 mydb = conn.connect(host = 'localhost', user = 'root', passwd = 'khair2255')
#
# ~\anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     270
#     271     if HAVE_CEXT and not use_pure:
# --> 272         return CMySQLConnection(*args, **kwargs)
# ...

# %%
cursor = mydb.cursor()

# %%
cursor.execute('show databases')  
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testkhair',)]

# %% [markdown]
# # 2. Create database called cardataset

# %%
cursor.execute('CREATE database IF NOT exists cardataset')

# %%
cursor.fetchall()
# Out:
# []

# %% [markdown]
# # 3. Create table with the column names

# %%
cursor.execute('CREATE TABLE cardataset.CAR(Buying VARCHAR(20), Maint VARCHAR(20), Doors VARCHAR(10), Persons VARCHAR(10),lugboot VARCHAR(20), safety VARCHAR(20), Class VARCHAR(20))')

# %%
cursor.execute('use cardataset')  
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('show tables')  
cursor.fetchall()
# Out:
# [('car',)]

# %%
cursor.execute('SELECT * from cardataset.car')  
cursor.fetchall()
# Out:
# []

# %% [markdown]
# # 4. Dumping the data in the car table

# %%
import csv
with open('car.data', 'r') as f: 
    glass_data = csv.reader(f, delimiter = '\n')  
    for i in glass_data: 
        x = i[0].split(',')  
        print(x)
        print(f'insert into car values ({str(i[0])})')
        cursor.execute(f'insert into car values ({str(x)[1:-1]})')
# Out:
# ['vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc']
# insert into car values (vhigh,vhigh,2,2,small,low,unacc)
# ['vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc']
# insert into car values (vhigh,vhigh,2,2,small,med,unacc)
# ['vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc']
# insert into car values (vhigh,vhigh,2,2,small,high,unacc)
# ['vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc']
# insert into car values (vhigh,vhigh,2,2,med,low,unacc)
# ['vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc']
# insert into car values (vhigh,vhigh,2,2,med,med,unacc)
# ['vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc']
# insert into car values (vhigh,vhigh,2,2,med,high,unacc)
# ['vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc']
# insert into car values (vhigh,vhigh,2,2,big,low,unacc)
# ['vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc']
# insert into car values (vhigh,vhigh,2,2,big,med,unacc)
# ['vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc']
# ...

# %%
cursor.execute('select * from cardataset.car')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# # 5. Check wheather all the data are available into the table
#
# 1728 instances are inserted. So, all are available

# %%
cursor.execute('select count(*) from cardataset.car')
cursor.fetchall()
# Out:
# [(1728,)]

# %% [markdown]
# # 6. Try to group all the data with COL1 and count occurences of each and every record based on col1 value

# %%
cursor.execute('select count(*), Buying from cardataset.car group by Buying')
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-113-f19672ce9ebe> in <module>
# ----> 1 cursor.execute('select count(*), Buying from cardataset.car group by Buying')
#       2 cursor.fetchall()
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     241         if not self._cnx or self._cnx.is_closed():
#     242             raise errors.ProgrammingError("Cursor is not connected", 2055)
# --> 243         self._cnx.handle_unread_result()
#     244
#     245         stmt = ''
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in handle_unread_result(self, prepared)
#     792             self.consume_results()
#     793         elif unread_result:
# --> 794             raise errors.InternalError("Unread result found")
#     795
# ...

# %% [markdown]
# # 7. Try to filter a record where col 3 value will be 4

# %%
cursor.execute('select * from cardataset.car where Doors = 4')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# # 8. Try to update a col 3 value with 8 wherever you have value equal to 2

# %%
cursor.execute('UPDATE cardataset.car SET Doors = "8" where Doors= "2"')

# %%
cursor.execute('SELECT * from car where Doors = 8')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '8', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# # 9. try to delete table

# %%
cursor.execute('DROP table cardataset.car')

# %%
cursor.execute('show tables') 
cursor.fetchall()
# Out:
# []

# %% [markdown]
# # 10. try to delete database

# %%
cursor.execute('DROP database cardataset')
